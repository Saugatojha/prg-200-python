# %% [markdown]
# Comments
# . Single Line Comment
# . Multi Line Comment
# ---

# %%
# This is used for single line comment

'''

This is used for multi line comment

'''

# %% [markdown]
# Display function in python

# %%
print("This is python programming class", end= " ")
print('This is PRG 200 class', end =" ")
print(''' We will learn basics of python and OOP concept ''')
# Out:
# This is python programming class This is PRG 200 class  We will learn basics of python and OOP concept

# %% [markdown]
# ## Operators in Python
# . Mathematical Operators: +, -, *, /
# . Relational Operators: <, >, <=, >=, !=

# %%
print(50+50)
print(50*2)
print(50/2)
print(30%4)
# Out:
# 100
# 100
# 25.0
# 2

# %% [markdown]
# ## Vairables

# %%
age = 20
name = "Manil"
roll = 35
salary = 3500.56

# %% [markdown]
# ## check data type of the variables

# %%
print(type(age))
print(type(name))
print(type(roll))
print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(type(age))
#       2 print(type(name))
#       3 print(type(roll))
#
# NameError: name 'age' is not defined

# %%
# print(f'''this is PRG 200 class. A student named (name) of age (age) with roll id (roll) s salary of (salary)''')
# Out:
# this is PRG 200 class. A student named (name) of age (age) with roll id (roll) s salary of (salary)

# %%
celsius = float(input("temp in celsius"));
fr=(celsius* 9/5) + 32;
print(f"the converted celsius in f is {fr} ");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 celsius = float(input("temp in celsius"));
#       2 fr=(celsius* 9/5) + 32;
#       3 print(f"the converted celsius in f is {fr} ");
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# convert cm to feet and inches
